# %% [markdown]
# # بطل السكري مشروع بايثون ⭐

# %%
#تسجيل مستخدم جديد
with open("children.txt","a") as file:
  pass

def register_user():
    #ادخال بيانات المستخدم


    print("\n" + "=" * 40)
    print("تسجيل مستخدم جديد")
    print("=" * 40)

    username = input("اسم المستخدم: ")
    password = input("كلمة المرور: ")
    child_name = input("اسم الطفل: ")
    age = int(input("عمر الطفل: "))
    gender = input("جنس الطفل: ")

#التحقق من تكرار اسم المستخدم
    found = False

    with open("children.txt","r") as file:

     for line in file:
      data = line.strip().split(",")

      if username==data[0]:
        found=True

#اذا اسم المستخدم مسجل سابقا

    if found:
      print("\nاسم المستخدم مستخدم مسبقاً، يرجى اختيار اسم مستخدم آخر.")

#اذا اسم المستخدم غير مسجل مسبقا

    else:
      child={
        "username":username,
        "password":password,
        "name":child_name,
        "age":age,
        "gender":gender
           }

#حفظ البيانات في الملف
    with open("children.txt","a") as file:

      file.write(
        f"{username},{password},{child_name},{age},{gender}\n" )

      print(f"\nتم إنشاء حساب الطفل {child_name} بنجاح.")
    return child

#----------------------------------------------------------------
#تسجيل الدخول ولي الأمر

def login_parent():

    print("\n" + "=" * 40)
    print("تسجيل الدخول")
    print("=" * 40)

    username = input("اسم المستخدم: ")
    password = input("كلمة المرور: ")

    found = False

    with  open("children.txt","r") as file:

     for line in file:
      data = line.strip().split(",")

      if username==data[0]and password==data[1]:
        found=True
        break


    if found:

     print("\nتم تسجيل الدخول بنجاح.")

     child = {
        "username": data[0],
        "password": data[1],
        "name": data[2],
        "age": data[3],
        "gender": data[4]
     }
     return child

    else:
     print("\nاسم المستخدم أو كلمة المرور غير صحيحة.")
     return None
 #----------------------------------------------------------------
 # تسجيل الطفل
def login_child():

  print("\n" + "=" * 40)
  print("تسجيل الدخول")
  print("=" * 40)

  username = input("اسم المستخدم: ")
  password = input("كلمة المرور: ")

  found = False

  with open("children.txt","r") as file:

   for line in file:
    data = line.strip().split(",")

    if username==data[0]and password==data[1]:
      found=True
      break

  if found:
   child = {
    "username": data[0],
    "password": data[1],
    "name": data[2],
    "age": data[3],
    "gender": data[4]
   }

   print(f"\nمرحباً   {child['name']}!")
   print("جاري الانتقال إلى المستويات...")
   return child


  else:
    print("\nاسم المستخدم أو كلمة المرور غير صحيحة.")
    return None
#----------------------------------------------------------------
#تعريف الدرجات والشارات التي يصل عليها الطفل
score = 0
titles =[]

def level_1(child_name):

    score = 0

    print("=" * 50)
    print("المستوى الأول: العادات الصحية")
    print("=" * 50)
    print(f"""
مرحباً {child_name}، اليوم سنتعلم كيف نحافظ على صحتنا بتعلم العادات الصحية،
وسنحصل على شارة جديدة! هيا بنا.
""")

    input("اضغط Enter للبدء...")

    questions = [

        {
            "question": "هل السكري يمنعني من اللعب مع أصدقائي؟",
            "choices": [
                "نعم",
                "لا، أستطيع اللعب مع تنظيم صحتي"
            ],
            "answer": 2
        },

        {
            "question": "هل آكل طوال اليوم؟",
            "choices": [
                "نعم",
                "لا، آكل في أوقات الوجبات"
            ],
            "answer": 2
        },

        {
            "question": "إذا شعرت بالجوع ....",
            "choices": [
                "أخبر بابا وماما",
                "آكل أي شيء"
            ],
            "answer": 1
        },

        {
            "question": "قبل أن آكل ....",
            "choices": [
                "أخبر بابا وماما",
                "آكل مباشرة"
            ],
            "answer": 1
        },

        {
            "question": "يجب عليك دائماً الحرص على شرب ....",
            "choices": [
                "العصائر",
                "الماء"
            ],
            "answer": 2
        }

    ]

    # ===== الأسئلة =====

    for q in questions:

        print("\n" + q["question"])

        for i, choice in enumerate(q["choices"], start=1):
            print(f"{i}. {choice}")

        while True:
            try:
                user = int(input("اختر الإجابة: "))
                if user in [1, 2]:
                    break
                print("الرجاء اختيار 1 أو 2 فقط.")
            except ValueError:
                print("الرجاء إدخال رقم صحيح.")

        if user == q["answer"]:

            print("⭐ إجابة صحيحة!")
            score += 20

        else:

            print("❌ إجابة خاطئة!")

            correct = q["choices"][q["answer"] - 1]

            print(f"✅ الإجابة الصحيحة: {correct}")

    # ===== النتيجة =====

    print("\n" + "=" * 50)
    print(f"⭐ درجتك هي: {score}/100")

    with open("progress.txt", "a", encoding="utf-8") as file:
        file.write(f"Level 1:{score}\n")

    if score >= 80:

        print(f"\n🎉 ممتاز يا {child_name}!")
        print("🏅 لقد حصلت على شارة جديدة!")
        print("🏅 بطل العادات الصحية")
        print("\nلنذهب إلى المستوى الثاني")

        return score, "بطل العادات الصحية"

    else:

        print("\n💪 محاولة جيدة")
        print("لكن لنلعب بشكل أفضل المرة القادمة، حسناً؟")

        return score, None


def level_2(child_name):

    score = 0

    print("=" * 50)
    print("المستوى الثاني: اختر طعامك")
    print("=" * 50)

    print(f"""
مرحباً يا {child_name}!

الكربوهيدرات تعطينا الطاقة لنلعب ونتعلم.
لكن تناول كمية كبيرة منها دون حساب قد يرفع مستوى السكر.

هيا نتعلم كيف نكون أبطالاً في حساب الكربوهيدرات!
""")

    input("اضغط Enter للبدء...")

    questions = [

        {
            "question": "الكربوهيدرات هي ....",
            "choices": [
                "طاقة تساعدني على اللعب والحركة ⚡",
                "اكل غير جيد"
            ],
            "answer": 1
        },

        {
            "question": "إذا أكلت كمية كبيرة جداً من الكربوهيدرات دون حساب، ماذا قد يحدث؟",
            "choices": [
                "قد يرتفع مستوى السكر 📈",
                "سأصبح أطول فوراً 😄"
            ],
            "answer": 1
        },

        {
            "question": "أين أجد الكربوهيدرات غالباً؟",
            "choices": [
                "في الخبز والأرز والمعكرونة 🍞🍚🍝",
                "في كل الطعام"
            ],
            "answer": 1
        },

        {
            "question": "أيهما أفضل كوجبة خفيفة؟",
            "choices": [
                "تفاحة 🍎",
                "عدة قطع كبيرة من الحلوى 🍬🍬🍬"
            ],
            "answer": 1
        },

        {
            "question": "أيهما أفضل لبطل السكري؟",
            "choices": [
                "ماما وبابا يحسبون لي الكاربوهيدرات",
                "أكل أي كمية دون حساب"
            ],
            "answer": 1
        }

    ]

    for q in questions:

        print("\n" + q["question"])

        for i, choice in enumerate(q["choices"], start=1):
            print(f"{i}. {choice}")

        while True:
            try:
                user = int(input("اختر الإجابة: "))

                if user in [1, 2]:
                    break

                print("اختر 1 أو 2 فقط.")

            except ValueError:
                print("الرجاء إدخال رقم صحيح.")

        if user == q["answer"]:

            print("⭐ إجابة صحيحة!")
            score += 20

        else:

            print("❌ إجابة خاطئة!")

            correct = q["choices"][q["answer"] - 1]

            print(f"✅ الإجابة الصحيحة: {correct}")

    print("\n" + "=" * 50)
    print(f"⭐ درجتك هي: {score}/100")

    with open("progress.txt", "a", encoding="utf-8") as file:
        file.write(f"Level 2:{score}\n")

    if score >= 80:

        print(f"\n🎉 رائع يا {child_name}!")
        print("🏅 لقد حصلت على شارة جديدة!")
        print("🏅 بطل الكربوهيدرات الذكي")

        return score, "بطل الكربوهيدرات الذكي"

    else:

        print("\n💪 محاولة جيدة!")
        print("هيا نجرب مرة أخرى لنحصل على الشارة.")

        return score, None


#############
def level_3(child_name):

    score = 0

    print("=" * 50)
    print("المستوى الثالث: بطل القرار الصحيح")
    print("=" * 50)

    print(f"""
مرحباً يا {child_name}!

أحياناً نواجه مواقف مفاجئة في المدرسة أو المنزل أو أثناء الخروج.
في هذا المستوى سنتعلم كيف نتخذ القرار الصحيح لنحافظ على صحتنا.

هيا نبدأ!
""")

    input("اضغط Enter للبدء...")

    questions = [

        {
            "question": "في المدرسة أعطاك صديقك حلوى 🍬، ماذا تفعل؟",
            "choices": [
                "أسأل المعلم أو أتواصل مع أهلي قبل أكلها",
                "آكلها مباشرة"
            ],
            "answer": 1
        },

        {
            "question": "وجدت عصيراً في الثلاجة 🧃، ماذا تفعل؟",
            "choices": [
                "أسأل إذا كان مناسباً لي وكمية الكربوهيدرات فيه",
                "أشربه كله مباشرة"
            ],
            "answer": 1
        },

        {
            "question": "في العيد كانت هناك الكثير من الحلويات 🍭🍫، ماذا تفعل؟",
            "choices": [
                "أختار كمية مناسبة وأخبر أهلي",
                "آكل كل ما أستطيع"
            ],
            "answer": 1
        },

        {
            "question": "في المطعم أحضرت القائمة 🍔🍟، ماذا تفعل أولاً؟",
            "choices": [
                "أختار وجبة مناسبة بمساعدة أهلي",
                "أطلب أكبر وجبة دون تفكير"
            ],
            "answer": 1
        },

        {
            "question": "كنت عند جدتي وقدمت لك وجبة جديدة 🍽️، ماذا تفعل؟",
            "choices": [
                "أسأل إذا كانت مناسبة لي وأخبر أهلي",
                "آكلها مباشرة"
            ],
            "answer": 1
        }

    ]

    for q in questions:

        print("\n" + q["question"])

        for i, choice in enumerate(q["choices"], start=1):
            print(f"{i}. {choice}")

        while True:
            try:
                user = int(input("اختر الإجابة: "))

                if user in [1, 2]:
                    break

                print("اختر 1 أو 2 فقط.")

            except ValueError:
                print("الرجاء إدخال رقم صحيح.")

        if user == q["answer"]:

            print("⭐ إجابة صحيحة!")
            score += 20

        else:

            print("❌ إجابة خاطئة!")

            correct = q["choices"][q["answer"] - 1]

            print(f"✅ الإجابة الصحيحة: {correct}")

            print("\n" + "=" * 50)
            print(f"⭐ درجتك هي: {score}/100")

            with open("progress.txt", "a", encoding="utf-8") as file:
              file.write(f"Level 3:{score}\n")

    if score >= 80:

        print(f"\n🎉 ممتاز يا {child_name}!")
        print("🏅 لقد حصلت على شارة جديدة!")
        print("🏅 بطل القرار الصحيح")

        return score, "بطل القرار الصحيح"

    else:

        print("\n💪 محاولة جيدة!")
        print("هيا نجرب مرة أخرى لنحصل على الشارة.")

        return score, None




###########
def level_4(child_name):
    score = 0

    print("=" * 50)
    print("المستوى الرابع: بطل الممارسات الصحية")
    print("=" * 50)

    print(f"""
{child_name}أحسنت يا !

الآن سنتعلم بعض الممارسات اليومية
التي تساعد أبطال السكري على المحافظة على صحتهم.
""")

    input("اضغط Enter للبدء...")

    questions = [
        {
            "question": "هل تساعد الحركة واللعب على المحافظة على الصحة؟",
            "choices": ["نعم 🏃", "لا"],
            "answer": 1
        },
        {
            "question": "هل النوم الجيد مهم لصحتي؟",
            "choices": ["نعم 😴", "لا"],
            "answer": 1
        },
        {
            "question": "إذا شعرت بتعب أو لم أشعر أنني بخير، ماذا أفعل؟",
            "choices": ["أخبر أهلي أو شخصاً بالغاً", "لا أخبر أحداً"],
            "answer": 1
        },
        {
            "question": "هل من الجيد أن أتبع تعليمات علاجي؟",
            "choices": ["نعم ✅", "لا"],
            "answer": 1
        },
        {
            "question": "أي عادة أفضل لبطل السكري؟",
            "choices": ["الحركة والنوم الجيد والطعام المناسب", "السهر وتجاهل صحتي"],
            "answer": 1
        }
    ]

    for q in questions:
        print("\n" + q["question"])
        for i, choice in enumerate(q["choices"], start=1):
            print(f"{i}. {choice}")

        try:
            user = int(input("اختر الإجابة (رقم): "))
            if user == q["answer"]:
                print("⭐ إجابة صحيحة!")
                score += 20
            else:
                print("❌ إجابة خاطئة!")
                print(f"✅ الإجابة الصحيحة هي: {q['choices'][q['answer'] - 1]}")
        except ValueError:
            print("❌ إدخال غير صالح! سيتم احتسابها إجابة خاطئة.")

    # نقلنا الطباعة للخارج لتكون بعد انتهاء كل الأسئلة
    print("\n" + "=" * 50)
    print(f"⭐ درجتك النهائية هي: {score}/100")

    with open("progress.txt", "a", encoding="utf-8") as file:
        file.write(f"Level 4:{score}\n")

    if score >= 80:
        print("\n🎉 ممتاز!")
        print("🏅 حصلت على شارة: بطل الممارسات الصحية")
        return score, "بطل الممارسات الصحية"
    else:
        print("\n💪 محاولة جيدة!")
        return score, None

##############
def level_5(child_name):

    score = 0

    print("=" * 50)
    print("المستوى الخامس: رحلة البطل")
    print("=" * 50)

    print(f"""
{child_name}مرحباً !

وصلت إلى المرحلة الأخيرة.

اليوم سنرافقك في رحلة كاملة،
ونرى هل أصبحت بطل السكري الحقيقي!
""")

    input("اضغط Enter للبدء...")

    questions = [

        {
            "question": f"استيقظ  صباحاً، ماذا يختار للإفطار؟",
            "choices": [
                "وجبة مناسبة مع معرفة الكربوهيدرات 🍳",
                "الكثير من الحلوى 🍬"
            ],
            "answer": 1
        },

        {
            "question": f"في المدرسة أعطى صديقٌ  قطعة حلوى، ماذا يفعل؟",
            "choices": [
                "يسأل شخصاً بالغاً أولاً",
                "يأكلها مباشرة"
            ],
            "answer": 1
        },

        {
            "question": f"حان وقت اللعب، ماذا يفعل؟",
            "choices": [
                "يلعب ويتحرك بنشاط ⚽",
                "يجلس طوال اليوم"
            ],
            "answer": 1
        },

        {
            "question": f"في زيارة عائلية وُجدت حلويات كثيرة، ماذا يفعل ؟",
            "choices": [
                "يختار كمية مناسبة",
                "يأكل كل الحلويات"
            ],
            "answer": 1
        },

        {
            "question": f"قبل النوم، ما أهم شيء يتذكره ؟",
            "choices": [
                "أن يهتم بصحته ويتبع العادات الصحيحة ❤️",
                "أن يتجاهل كل ما تعلمه"
            ],
            "answer": 1
        }

    ]

    for q in questions:

        print("\n" + q["question"])

        for i, choice in enumerate(q["choices"], start=1):
            print(f"{i}. {choice}")

        user = int(input("اختر الإجابة: "))

        if user == q["answer"]:
            print("⭐ إجابة صحيحة!")
            score += 20

        else:
            print("❌ إجابة خاطئة!")
            print(f"✅ الإجابة الصحيحة: {q['choices'][q['answer'] - 1]}")

    print("\n" + "=" * 50)
    print(f"⭐ درجتك هي: {score}/100")

    with open("progress.txt", "a", encoding="utf-8") as file:
        file.write(f"Level 5:{score}\n")

    if score >= 80:

        print(f"\n🎉{child_name} أحسنت يا !")
        print("🏅 لقد حصلت على الشارة الأخيرة!")
        print("👑 بطل السكري")

        return score, "بطل السكري"

    else:

        print("\n💪 اقتربت من الفوز بالشارة الأخيرة!")

        return score, None
#===============================================================
def total(child):

    total_score = 0
    titles = []

    score, badge = level_1(child["name"])
    total_score += score
    if badge:
        titles.append(badge)

    score, badge = level_2(child["name"])
    total_score += score
    if badge:
        titles.append(badge)

    score, badge = level_3(child["name"])
    total_score += score
    if badge:
        titles.append(badge)

    score, badge = level_4(child["name"])
    total_score += score
    if badge:
        titles.append(badge)

    score, badge = level_5(child["name"])
    total_score += score
    if badge:
        titles.append(badge)

    print("\n" + "=" * 50)
    print(f"🎉 تهانينا {child['name']}!")
    print(f"⭐ مجموع النقاط: {total_score}")

    print("\n🏅 الشارات التي حصلت عليها:")

    if titles:
        for title in titles:
            print("-", title)
    else:
        print("لم يتم الحصول على أي شارة")

    print("=" * 50)
#================================================================
#================================================================
import random

def parent_report(child):

    print("\n" + "=" * 50)
    print("📊 تقرير تقدم الطفل")
    print("=" * 50)

    print(f"👦 اسم الطفل: {child['name']}")
    print(f"🎂 العمر: {child['age']}")
    print(f"🧒 الجنس: {child['gender']}")
    print("\n📚 المستويات المكتملة:\n")

    scores = []

    performance = lambda score: "ممتاز 🌟" if score >= 90 else "جيد 👍" if score >= 70 else "يحتاج تحسين 💪"

    try:
        with open("progress.txt", "r", encoding="utf-8") as file:
            for line in file:

                data = line.strip().split(":")

                if len(data) != 2:
                    continue

                level_name = data[0]
                score = int(data[1])

                scores.append(score)

                status = performance(score)

                print(f"⭐ {level_name} → الدرجة: {score}/100 | التقييم: {status}")

        if len(scores) > 0:
            average = sum(scores) / len(scores)
            print(f"\n📈 متوسط الدرجات: {average:.2f}")
        else:
            print("لا يوجد تقدم مسجل بعد.")

    except FileNotFoundError:
        print("لا يوجد ملف تقدم حالياً.")

    tips = [
        "الالتزام بقياس السكر بانتظام يساعد على التحكم الأفضل بالسكري 🌟",
        "شرب الماء بانتظام عادة صحية مهمة لطفلك 💧",
        "النشاط البدني اليومي يساعد في الحفاظ على مستوى السكر ⚽",
        "احرص على توفير وجبات خفيفة صحية مثل الفواكه 🍎",
        "تعليم الطفل التعرف على أعراض انخفاض السكر مهم جداً 🚨",
        "الدعم النفسي والتشجيع يساعد الطفل على التعايش بثقة ❤️"
    ]

    daily_tip = random.choice(tips)

    print("\n💡 نصيحة اليوم:")
    print(daily_tip)

    print("=" * 50)
#----------------------------------------------------------------
#القائمة الرئيسية

print("=" * 40)
print("      بطل السكري")
print("=" * 40)

print("\nالقائمة الرئيسية")


print("1. تسجيل جديد")
print("2. تسجيل دخول")
print("3. خروج")

choice = input("\nاختر أحد الخيارات: ")
#----------------------------------------------------------------
#ولي الأمر

if choice in ["1", "١"]:

    print("\n" + "=" * 40)
    print("واجهة التسجيل ")
    print("=" * 40)

    #تسجيل جديد
    register_user()

 #----------------------------------------------------------------
 #تسجيل

elif choice in ["2","٢"]:

  print("1. ولي أمر")
  print("2. طفل")

  choice = input("\nاختر أحد الخيارات: ")

  if choice in ["1", "١"]:

    child = login_parent()

    if child:
        parent_report(child)

  elif choice in ["2","٢"]:
    child = login_child()

    if child:
     total(child)


#----------------------------------------------------------------
#خروج
elif choice in[ "3" ,"٣"]:
  print("\nشكراً لاستخدام تطبيق بطل السكري.")
  print("نتمنى لك يوماً سعيداً.")
#----------------------------------------------------------------
# خطأ بالاختيار
else:
  print("\nخيار غير صحيح، يرجى المحاولة مرة أخرى.")
# Out:
# ========================================
#       بطل السكري
# ========================================
#
# القائمة الرئيسية
# 1. تسجيل جديد
# 2. تسجيل دخول
# 3. خروج
#
# اختر أحد الخيارات: ٢
# 1. ولي أمر
# 2. طفل
#
# اختر أحد الخيارات: ١
#
# ========================================
# تسجيل الدخول
# ========================================
# اسم المستخدم: غلا
# كلمة المرور: ١٢٣
#
# تم تسجيل الدخول بنجاح.
#
# ==================================================
# 📊 تقرير تقدم الطفل
# ==================================================
# 👦 اسم الطفل: سوسو
# 🎂 العمر: 7
# 🧒 الجنس: بنت
#
# 📚 المستويات المكتملة:
#
# ⭐ Level 1 → الدرجة: 40/100 | التقييم: يحتاج تحسين 💪
# ⭐ Level 2 → الدرجة: 80/100 | التقييم: جيد 👍
# ⭐ Level 4 → الدرجة: 100/100 | التقييم: ممتاز 🌟
# ⭐ Level 5 → الدرجة: 100/100 | التقييم: ممتاز 🌟
#
# 📈 متوسط الدرجات: 80.00
#
# 💡 نصيحة اليوم:
# شرب الماء بانتظام عادة صحية مهمة لطفلك 💧
# ==================================================

# %% [markdown]
# # What was the most challenging part?
# The most challenging part of this project was converting our Python console application into a Streamlit application. Adapting the code from using input() and print() to an interactive graphical user interface required a lot of testing and debugging.
#
#
# # Which concept did you enjoy the most?**
# The concept we enjoyed the most was creating the educational levels and quizzes for children. It was exciting to design interactive questions and reward users with badges and achievements.
#
#
#
# #What would you improve if you had more time?**
#
# If we had more time, we would integrate our application with a diabetes tracking app to monitor blood sugar levels and provide personalized recommendations. We would also add voice support for the questions to make the application more engaging and accessible for young children
